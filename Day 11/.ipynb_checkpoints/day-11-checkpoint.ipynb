# %%
import numpy as np

# %%
def hypothesis(x, theta0, theta1):
    y = theta0 + theta1 * x
    return y

# %%
def cost(x, y, theta0, theta1):
    return (1/2*len(x)) * np.sum(np.square(hypothesis(x, theta0, theta1) - y))

# %%
def gradient(theta0, theta1, learning_rate, x, y, iter):
    t0 = theta0
    t1 = theta1
    history = []
    for i in range(iter):
        prediction = hypothesis(x, t0, t1)
        temp0 = t0 - learning_rate / len(x) * np.sum(prediction - y)
        temp1 = t1 - learning_rate / len(x) * np.sum(np.multiply((prediction - y), x))
        t0 = temp0
        t1 = temp1
        history.append([t0, t1])
    return history

# %%
x = 2 * np.random.rand(100,1)
y = 4 + 3 * x + np.random.randn(100,1)
theta0 = 0
theta1= 0

history = gradient(theta0, theta1, 0.05, x, y, 100)
theta0 = history[-1][0]
theta1 = history[-1][1]

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

sns.set()
my_dpi=96
for i in range(len(history)):
    ts = history[i]
    predict = hypothesis(x, ts[0], ts[1])
    plt.figure(figsize=(480/my_dpi, 480/my_dpi), dpi=my_dpi)
    # df  = pd.DataFrame({'x':x, 'y':predict})
    # sns.lineplot(x='x', y='y', data=df)
    # sns.lmplot(x='x', y='y', data=df, color='red')
    plt.xlim(0, 2)
    plt.ylim(0, 14)
    plt.title("Linear Regression in Action")
    plt.plot(x, predict)
    plt.plot(x, y, marker='*', linestyle='None')
    filename='imgs/'+str(i).zfill(4)+'.png'
    plt.savefig(filename, dpi=96)
# Out:
# /Users/jeison/miniconda3/envs/100-days-of-ML/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   # Remove the CWD from sys.path while we load stuff.
